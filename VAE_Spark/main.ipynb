# %%
import movielens

data = movielens.Movielens()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-12460c61f9f6> in <module>
#       1 import movielens
#       2
# ----> 3 data = movielens.Movielens()
#
# ~\Desktop\Masters\1.USML\project\movielens.py in __init__(self)
#       7     def __init__(self):
#       8         if os.path.isfile('data/movie_data_merge'):
# ----> 9             self.movie_data_merge = pd.read_pickle('data/movie_data_merge')
#      10         else:
#      11             self.ratings = pd.read_csv('data/ratings_small.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\pickle.py in read_pickle(filepath_or_buffer, compression)
#     167     if not isinstance(fp_or_buf, str) and compression == "infer":
#     168         compression = None
# --> 169     f, fh = get_handle(fp_or_buf, "rb", compression=compression, is_text=False)
#     170
#     171     # 1) try standard library Pickle
#
# ...

# %%
data.movie_data_merge.head()
# Out:
#        adult     budget                           genres       id    imdb_id  \
# 314    False   25000000                     Drama, Crime    278.0  tt0111161
# 837    False    6000000                     Drama, Crime    238.0  tt0068646
# 10345  False   13200000           Comedy, Drama, Romance  19404.0  tt0112870
# 12525  False  185000000   Drama, Action, Crime, Thriller    155.0  tt0468569
# 2854   False   63000000                            Drama    550.0  tt0137523
#
#       original_language               original_title  \
# 314                  en     The Shawshank Redemption
# 837                  en                The Godfather
# 10345                hi  Dilwale Dulhania Le Jayenge
# 12525                en              The Dark Knight
# 2854                 en                   Fight Club
#
#                                                 overview popularity  \
# 314    Framed in the 1940s for the double murder of h...    51.6454
# ...
